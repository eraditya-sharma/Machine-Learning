# %%
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd
import numpy as np
from sklearn import datasets

# %%
crdata = pd.read_excel(r"C:\Users\Aditya Sharma\Desktop\KaggleData-master\Cricket_Data.xlsx")

# %%
crdata
# Out:
#     Mat  Inns   Runs    Ave      SR CATEGORY
# 0    58   104   4154  41.95   51.49     TEST
# 1   147   143   5238  39.68   85.25      ODI
# 2    71   122   6147  53.92   58.22     TEST
# 3   211   203   9779  58.20   92.12      ODI
# 4    62    58   2102  48.88  136.22      T20
# 5   200   329  15921  53.78   58.22     TEST
# 6   463   452  18426  44.83   86.23      ODI
# 7    35    22    271  16.93  153.10      T20
# 8    41    27    670  29.13  114.52      ODI
# 9    90   144   4876  38.09   59.11     TEST
# 10  321   274  10046  51.25   88.13      ODI
# 11   93    80   1487  37.17  127.09      T20
# 12   50    86   3150  40.90   51.22     TEST
# 13   90    87   2962  35.26   78.63      ODI
# 14   20    20    375  20.83  113.29      T20
# 15   18    31    768  26.48   53.14     TEST
# 16  226   194   5615  35.31   93.50      ODI
# 17   78    66   1605  29.18  134.87      T20
# 18   32    57   2068  37.60   44.16     TEST
# 19   58    57   2184  39.70   80.23      ODI
# ...

# %%
x_input = crdata.iloc[:,0:5] 
y_target = crdata.iloc[:,5]

# %%
x_input
# Out:
#     Mat  Inns   Runs    Ave      SR
# 0    58   104   4154  41.95   51.49
# 1   147   143   5238  39.68   85.25
# 2    71   122   6147  53.92   58.22
# 3   211   203   9779  58.20   92.12
# 4    62    58   2102  48.88  136.22
# 5   200   329  15921  53.78   58.22
# 6   463   452  18426  44.83   86.23
# 7    35    22    271  16.93  153.10
# 8    41    27    670  29.13  114.52
# 9    90   144   4876  38.09   59.11
# 10  321   274  10046  51.25   88.13
# 11   93    80   1487  37.17  127.09
# 12   50    86   3150  40.90   51.22
# 13   90    87   2962  35.26   78.63
# 14   20    20    375  20.83  113.29
# 15   18    31    768  26.48   53.14
# 16  226   194   5615  35.31   93.50
# 17   78    66   1605  29.18  134.87
# 18   32    57   2068  37.60   44.16
# 19   58    57   2184  39.70   80.23
# 20   15    15    255  18.21  102.82
# 21   93    89   3361  38.19   90.30
# 22   42    42   1596  45.60  161.53
# 23   64   117   6199  61.37   55.49
# 24  108    94   3431  41.84   86.35
# ...

# %%
xcat = x_input.values.reshape(75,5)
y_target = y_target.values.reshape(75,1)

# %%
x_train = xcat[:53]
x_test = xcat[53:]

y_train = y_target[:53]
y_test = y_target[53:]

# %%
x_test
# Out:
# array([[7.1000e+01, 7.0000e+01, 2.1400e+03, 3.5660e+01, 1.3621e+02],
#        [4.7000e+01, 8.9000e+01, 2.5860e+03, 2.9380e+01, 4.6610e+01],
#        [1.5900e+02, 1.5600e+02, 5.9760e+03, 4.2990e+01, 8.6380e+01],
#        [7.5000e+01, 7.3000e+01, 2.2710e+03, 3.4400e+01, 1.3288e+02],
#        [5.0000e+00, 9.0000e+00, 8.6000e+01, 1.0750e+01, 2.6700e+01],
#        [8.3000e+01, 6.9000e+01, 1.9760e+03, 3.4060e+01, 8.1780e+01],
#        [1.7000e+01, 1.5000e+01, 1.7100e+02, 1.5540e+01, 1.0891e+02],
#        [1.1900e+02, 2.0500e+02, 9.0220e+03, 4.7230e+01, 5.0170e+01],
#        [1.6900e+02, 1.6600e+02, 7.6960e+03, 4.9650e+01, 8.9300e+01],
#        [4.4000e+01, 4.4000e+01, 1.2770e+03, 3.3600e+01, 1.3205e+02],
#        [1.0900e+02, 9.7000e+01, 2.5880e+03, 3.6970e+01, 1.0121e+02],
#        [6.1000e+01, 5.3000e+01, 1.0840e+03, 2.8520e+01, 1.3879e+02],
#        [1.1400e+02, 1.9100e+02, 8.7650e+03, 5.0660e+01, 5.4510e+01],
#        [2.2800e+02, 2.1800e+02, 9.5770e+03, 5.3500e+01, 1.0109e+02],
# ...

# %%
trainer = KNeighborsClassifier()

# %%
learner = trainer.fit(x_train,y_train)
# Out:
# C:\Users\Aditya Sharma\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   """Entry point for launching an IPython kernel.

# %%
Ya = y_test

# %%
Yp = learner.predict(x_test)

# %%
accscore = accuracy_score(Ya,Yp)*100
accscore
# Out:
# 40.909090909090914

# %%
p = learner.predict
